# %%
import cv2
import matplotlib.pyplot as plt

# %%
bgr_number  = cv2.imread('images/2.jpg')
rgb_number  = cv2.cvtColor(bgr_number, cv2.COLOR_BGR2RGB)
gray_number = cv2.cvtColor(bgr_number, cv2.COLOR_BGR2GRAY)

fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15, 10))
ax1.imshow(bgr_number)
ax2.imshow(rgb_number)
ax3.imshow(gray_number)
plt.show()
